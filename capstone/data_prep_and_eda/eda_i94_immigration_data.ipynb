# %% [markdown]
# ### EDA on I94 Immigration Data
# - I94YR - 4 digit year
# - I94MON - Numeric month
# - I94CIT & I94RES - This format shows all the valid and invalid codes for processing
# - I94PORT - This format shows all the valid and invalid codes for processing
# - ARRDATE is the Arrival Date in the USA. It is a SAS date numeric field that a permament format has not been applied.  Please apply whichever date format works for you.
# - I94MODE - There are missing values as well as not reported (9)
# - I94ADDR - There is lots of invalid codes in this variable and the list below shows what we have found to be valid, everything else goes into 'other'
# - DEPDATE is the Departure Date from the USA. It is a SAS date numeric field that a permament format has not been applied.  Please apply whichever date format works for you.
# - I94BIR - Age of Respondent in Years
# - I94VISA - Visa codes collapsed into three categories*/
# - COUNT - Used for summary statistics
# - DTADFILE - Character Date Field - Date added to I-94 Files - CIC does not use
# - VISAPOST - Department of State where where Visa was issued - CIC does not use
# - OCCUP - Occupation that will be performed in U.S. - CIC does not use
# - ENTDEPA - Arrival Flag - admitted or paroled into the U.S. - CIC does not use
# - ENTDEPD - Departure Flag - Departed, lost I-94 or is deceased - CIC does not use
# - ENTDEPU - Update Flag - Either apprehended, overstayed, adjusted to perm residence - CIC does not use
# - MATFLAG - Match flag - Match of arrival and departure records
# - BIRYEAR - 4 digit year of birth
# - DTADDTO - Character Date Field - Date to which admitted to U.S. (allowed to stay until) - CIC does not use
# - GENDER - Non-immigrant sex
# - INSNUM - INS number
# - AIRLINE - Airline used to arrive in U.S.
# - ADMNUM - Admission Number
# - FLTNO - Flight number of Airline used to arrive in U.S.
# - VISATYPE - Class of admission legally admitting the non-immigrant to temporarily stay in U.S.

# %%
import os
import datetime
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 1028)
import configparser

import boto3

from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, IntegerType, DateType, LongType, MapType

# %%
# config = configparser.ConfigParser()
# config.read('/home/workspace/capstone.cfg')
# Out:
# ['/home/workspace/capstone.cfg']

# %%
# os.environ["AWS_ACCESS_KEY_ID"] = config['AWS']['AWS_ACCESS_KEY_ID']
# os.environ["AWS_SECRET_ACCESS_KEY"] = config['AWS']['AWS_SECRET_ACCESS_KEY']
# input_data_dir = config['S3']['INPUT_S3_BUCKET']

# %%
# Init a SparkSession object
spark = SparkSession \
    .builder \
    .config("spark.jars.packages", "saurfang:spark-sas7bdat:2.0.0-s_2.11,org.apache.hadoop:hadoop-aws:2.7.0") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
# load i94addr dictionary - map the i94addr values
i94addr_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94addr_dictionary.csv')

# load i94 immigration data
i94_immigration_spark_df =spark.read \
    .format('com.github.saurfang.sas.spark') \
    .load(f'{input_data_dir}/i94_immigration_2016_raw/i94_apr16_sub.sas7bdat',
          forceLowercaseNames=True,
          inferLong=True)

# Cast some columns to the ideal type
i94_immigration_spark_df = i94_immigration_spark_df \
    .withColumn('cicid',  F.col('cicid').cast('integer').cast('string')) \
    .withColumn('i94yr',  F.col('i94yr').cast('integer')) \
    .withColumn('i94mon', F.col('i94mon').cast('integer')) \
    .withColumn('i94cit', F.col('i94cit').cast('integer')) \
    .withColumn("i94res", F.col('i94res').cast('integer')) \
    .withColumn("i94mode", F.col('i94mode').cast('integer')) \
    .withColumn("i94bir", F.col('i94bir').cast('integer')) \
    .withColumn("i94visa", F.col('i94visa').cast('integer'))

# load i94addr dictionary - map the i94addr values
i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94addr_dictionary_spark_df, i94_immigration_spark_df.i94addr==i94addr_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94addr') \
    .withColumnRenamed('value', 'i94addr')

# around 5% records, should not drop them
# i94_immigration_spark_df.filter(F.col('value').isNull()).count() / i94_immigration_spark_df.count()

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94addr_DICTIONARY', ['i94addr'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  depdate  \
# 0     6   2016       4     692     692     XXX  20573.0      NaN      NaN
# 1     7   2016       4     254     276     ATL  20551.0      1.0      NaN
# 2    15   2016       4     101     101     WAS  20545.0      1.0  20691.0
# 3    16   2016       4     101     101     NYC  20545.0      1.0  20567.0
# 4    17   2016       4     101     101     NYC  20545.0      1.0  20567.0
# 5    18   2016       4     101     101     NYC  20545.0      1.0  20555.0
# 6    19   2016       4     101     101     NYC  20545.0      1.0  20558.0
# 7    20   2016       4     101     101     NYC  20545.0      1.0  20558.0
# 8    21   2016       4     101     101     NYC  20545.0      1.0  20553.0
# 9    22   2016       4     101     101     NYC  20545.0      1.0  20562.0
#
#    i94bir  i94visa  count  dtadfile visapost occup entdepa entdepd entdepu  \
# 0      37        2    1.0      None     None  None       T    None       U
# 1      25        3    1.0  20130811      SEO  None       G    None       Y
# 2      55        2    1.0  20160401     None  None       T       O    None
# 3      28        2    1.0  20160401     None  None       O       O    None
# 4       4        2    1.0  20160401     None  None       O       O    None
# 5      57        1    1.0  20160401     None  None       O       O    None
# 6      63        2    1.0  20160401     None  None       O       K    None
# 7      57        2    1.0  20160401     None  None       O       K    None
# 8      46        2    1.0  20160401     None  None       O       O    None
# 9      48        1    1.0  20160401     None  None       O       O    None
#
#   matflag  biryear   dtaddto gender insnum airline        admnum  fltno  \
# 0    None   1979.0  10282016   None   None    None  1.897628e+09   None
# 1    None   1991.0       D/S      M   None    None  3.736796e+09  00296
# 2       M   1961.0  09302016      M   None      OS  6.666432e+08     93
# 3       M   1988.0  09302016   None   None      AA  9.246846e+10  00199
# 4       M   2012.0  09302016   None   None      AA  9.246846e+10  00199
# 5       M   1959.0  09302016   None   None      AZ  9.247104e+10  00602
# 6       M   1953.0  09302016   None   None      AZ  9.247140e+10  00602
# 7       M   1959.0  09302016   None   None      AZ  9.247161e+10  00602
# 8       M   1970.0  09302016   None   None      AZ  9.247080e+10  00602
# 9       M   1968.0  09302016   None   None      AZ  9.247849e+10  00608
#
#   visatype                    i94addr
# 0       B2  NOT_IN_i94addr_DICTIONARY
# 1       F1                    ALABAMA
# 2       B2                   MICHIGAN
# 3       B2              MASSACHUSETTS
# 4       B2              MASSACHUSETTS
# 5       B1                   MICHIGAN
# 6       B2                 NEW JERSEY
# 7       B2                 NEW JERSEY
# 8       B2                   NEW YORK
# 9       B1                   NEW YORK

# %%
# load i94cit dictionary - map the i94cit values
i94cit_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94cit_dictionary.csv')
# i94cit_dictionary_spark_df - replace values in value cells of records whose value cells start with "INVALID: ", "No Country Code " and "should not show"
i94cit_dictionary_spark_df = i94cit_dictionary_spark_df.withColumn('value', 
                                      F.when(F.col('value').rlike('INVALID: ') | F.col('value').rlike('No Country Code ') | F.col('value').rlike('should not show')
                                             , 'IN_i94cit_DICTIONARY_BUT_INVALID_UNKNOWN_NOTSHOW') \
                                     .otherwise(F.col('value')))

i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94cit_dictionary_spark_df, i94_immigration_spark_df.i94cit==i94cit_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94cit') \
    .withColumnRenamed('value', 'i94cit')

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94cit_DICTIONARY', ['i94cit'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  i94res i94port  arrdate  i94mode  depdate  i94bir  \
# 0     6   2016       4     692     XXX  20573.0      NaN      NaN      37
# 1     7   2016       4     276     ATL  20551.0      1.0      NaN      25
# 2    15   2016       4     101     WAS  20545.0      1.0  20691.0      55
# 3    16   2016       4     101     NYC  20545.0      1.0  20567.0      28
# 4    17   2016       4     101     NYC  20545.0      1.0  20567.0       4
# 5    18   2016       4     101     NYC  20545.0      1.0  20555.0      57
# 6    19   2016       4     101     NYC  20545.0      1.0  20558.0      63
# 7    20   2016       4     101     NYC  20545.0      1.0  20558.0      57
# 8    21   2016       4     101     NYC  20545.0      1.0  20553.0      46
# 9    22   2016       4     101     NYC  20545.0      1.0  20562.0      48
#
#    i94visa  count  dtadfile visapost occup entdepa entdepd entdepu matflag  \
# 0        2    1.0      None     None  None       T    None       U    None
# 1        3    1.0  20130811      SEO  None       G    None       Y    None
# 2        2    1.0  20160401     None  None       T       O    None       M
# 3        2    1.0  20160401     None  None       O       O    None       M
# 4        2    1.0  20160401     None  None       O       O    None       M
# 5        1    1.0  20160401     None  None       O       O    None       M
# 6        2    1.0  20160401     None  None       O       K    None       M
# 7        2    1.0  20160401     None  None       O       K    None       M
# 8        2    1.0  20160401     None  None       O       O    None       M
# 9        1    1.0  20160401     None  None       O       O    None       M
#
#    biryear   dtaddto gender insnum airline        admnum  fltno visatype  \
# 0   1979.0  10282016   None   None    None  1.897628e+09   None       B2
# 1   1991.0       D/S      M   None    None  3.736796e+09  00296       F1
# 2   1961.0  09302016      M   None      OS  6.666432e+08     93       B2
# 3   1988.0  09302016   None   None      AA  9.246846e+10  00199       B2
# 4   2012.0  09302016   None   None      AA  9.246846e+10  00199       B2
# 5   1959.0  09302016   None   None      AZ  9.247104e+10  00602       B1
# 6   1953.0  09302016   None   None      AZ  9.247140e+10  00602       B2
# 7   1959.0  09302016   None   None      AZ  9.247161e+10  00602       B2
# 8   1970.0  09302016   None   None      AZ  9.247080e+10  00602       B2
# 9   1968.0  09302016   None   None      AZ  9.247849e+10  00608       B1
#
#                      i94addr                    i94cit
# 0  NOT_IN_i94addr_DICTIONARY                   ECUADOR
# 1                    ALABAMA  NOT_IN_i94cit_DICTIONARY
# 2                   MICHIGAN                   ALBANIA
# 3              MASSACHUSETTS                   ALBANIA
# 4              MASSACHUSETTS                   ALBANIA
# 5                   MICHIGAN                   ALBANIA
# 6                 NEW JERSEY                   ALBANIA
# 7                 NEW JERSEY                   ALBANIA
# 8                   NEW YORK                   ALBANIA
# 9                   NEW YORK                   ALBANIA

# %%
# load i94mode dictionary - map the i94mode values
i94mode_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94mode_dictionary.csv')

i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94mode_dictionary_spark_df, i94_immigration_spark_df.i94mode==i94mode_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94mode') \
    .withColumnRenamed('value', 'i94mode')

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94mode_DICTIONARY', ['i94mode'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  i94res i94port  arrdate  depdate  i94bir  i94visa  \
# 0     6   2016       4     692     XXX  20573.0      NaN      37        2
# 1     7   2016       4     276     ATL  20551.0      NaN      25        3
# 2    15   2016       4     101     WAS  20545.0  20691.0      55        2
# 3    16   2016       4     101     NYC  20545.0  20567.0      28        2
# 4    17   2016       4     101     NYC  20545.0  20567.0       4        2
# 5    18   2016       4     101     NYC  20545.0  20555.0      57        1
# 6    19   2016       4     101     NYC  20545.0  20558.0      63        2
# 7    20   2016       4     101     NYC  20545.0  20558.0      57        2
# 8    21   2016       4     101     NYC  20545.0  20553.0      46        2
# 9    22   2016       4     101     NYC  20545.0  20562.0      48        1
#
#    count  dtadfile visapost occup entdepa entdepd entdepu matflag  biryear  \
# 0    1.0      None     None  None       T    None       U    None   1979.0
# 1    1.0  20130811      SEO  None       G    None       Y    None   1991.0
# 2    1.0  20160401     None  None       T       O    None       M   1961.0
# 3    1.0  20160401     None  None       O       O    None       M   1988.0
# 4    1.0  20160401     None  None       O       O    None       M   2012.0
# 5    1.0  20160401     None  None       O       O    None       M   1959.0
# 6    1.0  20160401     None  None       O       K    None       M   1953.0
# 7    1.0  20160401     None  None       O       K    None       M   1959.0
# 8    1.0  20160401     None  None       O       O    None       M   1970.0
# 9    1.0  20160401     None  None       O       O    None       M   1968.0
#
#     dtaddto gender insnum airline        admnum  fltno visatype  \
# 0  10282016   None   None    None  1.897628e+09   None       B2
# 1       D/S      M   None    None  3.736796e+09  00296       F1
# 2  09302016      M   None      OS  6.666432e+08     93       B2
# 3  09302016   None   None      AA  9.246846e+10  00199       B2
# 4  09302016   None   None      AA  9.246846e+10  00199       B2
# 5  09302016   None   None      AZ  9.247104e+10  00602       B1
# 6  09302016   None   None      AZ  9.247140e+10  00602       B2
# 7  09302016   None   None      AZ  9.247161e+10  00602       B2
# 8  09302016   None   None      AZ  9.247080e+10  00602       B2
# 9  09302016   None   None      AZ  9.247849e+10  00608       B1
#
#                      i94addr                    i94cit  \
# 0  NOT_IN_i94addr_DICTIONARY                   ECUADOR
# 1                    ALABAMA  NOT_IN_i94cit_DICTIONARY
# 2                   MICHIGAN                   ALBANIA
# 3              MASSACHUSETTS                   ALBANIA
# 4              MASSACHUSETTS                   ALBANIA
# 5                   MICHIGAN                   ALBANIA
# 6                 NEW JERSEY                   ALBANIA
# 7                 NEW JERSEY                   ALBANIA
# 8                   NEW YORK                   ALBANIA
# 9                   NEW YORK                   ALBANIA
#
#                      i94mode
# 0  NOT_IN_i94mode_DICTIONARY
# 1                        Air
# 2                        Air
# 3                        Air
# 4                        Air
# 5                        Air
# 6                        Air
# 7                        Air
# 8                        Air
# 9                        Air

# %%
# load i94port dictionary - map the i94port values
i94port_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94port_dictionary.csv')

# # i94port_dictionary_spark_df - fitler out records whose value cells start with "No PORT Code "
i94port_dictionary_spark_df = i94port_dictionary_spark_df.withColumn('value', 
                                      F.when(F.col('value').rlike('No PORT Code '), 'IN_i94cit_DICTIONARY_BUT_NO_PORT_CODE') \
                                     .otherwise(F.col('value')))

i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94port_dictionary_spark_df, i94_immigration_spark_df.i94port==i94port_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94port') \
    .withColumnRenamed('value', 'i94port')

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94port_DICTIONARY', ['i94port'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  i94res  arrdate  depdate  i94bir  i94visa  count  \
# 0     6   2016       4     692  20573.0      NaN      37        2    1.0
# 1     7   2016       4     276  20551.0      NaN      25        3    1.0
# 2    15   2016       4     101  20545.0  20691.0      55        2    1.0
# 3    16   2016       4     101  20545.0  20567.0      28        2    1.0
# 4    17   2016       4     101  20545.0  20567.0       4        2    1.0
# 5    18   2016       4     101  20545.0  20555.0      57        1    1.0
# 6    19   2016       4     101  20545.0  20558.0      63        2    1.0
# 7    20   2016       4     101  20545.0  20558.0      57        2    1.0
# 8    21   2016       4     101  20545.0  20553.0      46        2    1.0
# 9    22   2016       4     101  20545.0  20562.0      48        1    1.0
#
#    dtadfile visapost occup entdepa entdepd entdepu matflag  biryear   dtaddto  \
# 0      None     None  None       T    None       U    None   1979.0  10282016
# 1  20130811      SEO  None       G    None       Y    None   1991.0       D/S
# 2  20160401     None  None       T       O    None       M   1961.0  09302016
# 3  20160401     None  None       O       O    None       M   1988.0  09302016
# 4  20160401     None  None       O       O    None       M   2012.0  09302016
# 5  20160401     None  None       O       O    None       M   1959.0  09302016
# 6  20160401     None  None       O       K    None       M   1953.0  09302016
# 7  20160401     None  None       O       K    None       M   1959.0  09302016
# 8  20160401     None  None       O       O    None       M   1970.0  09302016
# 9  20160401     None  None       O       O    None       M   1968.0  09302016
#
#   gender insnum airline        admnum  fltno visatype  \
# 0   None   None    None  1.897628e+09   None       B2
# 1      M   None    None  3.736796e+09  00296       F1
# 2      M   None      OS  6.666432e+08     93       B2
# 3   None   None      AA  9.246846e+10  00199       B2
# 4   None   None      AA  9.246846e+10  00199       B2
# 5   None   None      AZ  9.247104e+10  00602       B1
# 6   None   None      AZ  9.247140e+10  00602       B2
# 7   None   None      AZ  9.247161e+10  00602       B2
# 8   None   None      AZ  9.247080e+10  00602       B2
# 9   None   None      AZ  9.247849e+10  00608       B1
#
#                      i94addr                    i94cit  \
# 0  NOT_IN_i94addr_DICTIONARY                   ECUADOR
# 1                    ALABAMA  NOT_IN_i94cit_DICTIONARY
# 2                   MICHIGAN                   ALBANIA
# 3              MASSACHUSETTS                   ALBANIA
# 4              MASSACHUSETTS                   ALBANIA
# 5                   MICHIGAN                   ALBANIA
# 6                 NEW JERSEY                   ALBANIA
# 7                 NEW JERSEY                   ALBANIA
# 8                   NEW YORK                   ALBANIA
# 9                   NEW YORK                   ALBANIA
#
#                      i94mode                i94port
# 0  NOT_IN_i94mode_DICTIONARY  NOT REPORTED/UNKNOWN
# 1                        Air            ATLANTA, GA
# 2                        Air          WASHINGTON DC
# 3                        Air           NEW YORK, NY
# 4                        Air           NEW YORK, NY
# 5                        Air           NEW YORK, NY
# 6                        Air           NEW YORK, NY
# 7                        Air           NEW YORK, NY
# 8                        Air           NEW YORK, NY
# 9                        Air           NEW YORK, NY

# %%
# load i94res dictionary - map the i94res values
i94res_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94res_dictionary.csv')

# i94res_dictionary_spark_df - replace values in value cells of records whose value cells start with "INVALID: ", "No Country Code " and "should not show"
i94res_dictionary_spark_df = i94res_dictionary_spark_df.withColumn('value', 
                                      F.when(F.col('value').rlike('INVALID: ') | F.col('value').rlike('No Country Code ') | F.col('value').rlike('should not show')
                                             , 'IN_i94res_DICTIONARY_BUT_INVALID_UNKNOWN_NOTSHOW') \
                                     .otherwise(F.col('value')))

i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94res_dictionary_spark_df, i94_immigration_spark_df.i94res==i94res_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94res') \
    .withColumnRenamed('value', 'i94res')

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94res_DICTIONARY', ['i94res'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  arrdate  depdate  i94bir  i94visa  count  dtadfile  \
# 0     6   2016       4  20573.0      NaN      37        2    1.0      None
# 1     7   2016       4  20551.0      NaN      25        3    1.0  20130811
# 2    15   2016       4  20545.0  20691.0      55        2    1.0  20160401
# 3    16   2016       4  20545.0  20567.0      28        2    1.0  20160401
# 4    17   2016       4  20545.0  20567.0       4        2    1.0  20160401
# 5    18   2016       4  20545.0  20555.0      57        1    1.0  20160401
# 6    19   2016       4  20545.0  20558.0      63        2    1.0  20160401
# 7    20   2016       4  20545.0  20558.0      57        2    1.0  20160401
# 8    21   2016       4  20545.0  20553.0      46        2    1.0  20160401
# 9    22   2016       4  20545.0  20562.0      48        1    1.0  20160401
#
#   visapost occup entdepa entdepd entdepu matflag  biryear   dtaddto gender  \
# 0     None  None       T    None       U    None   1979.0  10282016   None
# 1      SEO  None       G    None       Y    None   1991.0       D/S      M
# 2     None  None       T       O    None       M   1961.0  09302016      M
# 3     None  None       O       O    None       M   1988.0  09302016   None
# 4     None  None       O       O    None       M   2012.0  09302016   None
# 5     None  None       O       O    None       M   1959.0  09302016   None
# 6     None  None       O       K    None       M   1953.0  09302016   None
# 7     None  None       O       K    None       M   1959.0  09302016   None
# 8     None  None       O       O    None       M   1970.0  09302016   None
# 9     None  None       O       O    None       M   1968.0  09302016   None
#
#   insnum airline        admnum  fltno visatype                    i94addr  \
# 0   None    None  1.897628e+09   None       B2  NOT_IN_i94addr_DICTIONARY
# 1   None    None  3.736796e+09  00296       F1                    ALABAMA
# 2   None      OS  6.666432e+08     93       B2                   MICHIGAN
# 3   None      AA  9.246846e+10  00199       B2              MASSACHUSETTS
# 4   None      AA  9.246846e+10  00199       B2              MASSACHUSETTS
# 5   None      AZ  9.247104e+10  00602       B1                   MICHIGAN
# 6   None      AZ  9.247140e+10  00602       B2                 NEW JERSEY
# 7   None      AZ  9.247161e+10  00602       B2                 NEW JERSEY
# 8   None      AZ  9.247080e+10  00602       B2                   NEW YORK
# 9   None      AZ  9.247849e+10  00608       B1                   NEW YORK
#
#                      i94cit                    i94mode                i94port  \
# 0                   ECUADOR  NOT_IN_i94mode_DICTIONARY  NOT REPORTED/UNKNOWN
# 1  NOT_IN_i94cit_DICTIONARY                        Air            ATLANTA, GA
# 2                   ALBANIA                        Air          WASHINGTON DC
# 3                   ALBANIA                        Air           NEW YORK, NY
# 4                   ALBANIA                        Air           NEW YORK, NY
# 5                   ALBANIA                        Air           NEW YORK, NY
# 6                   ALBANIA                        Air           NEW YORK, NY
# 7                   ALBANIA                        Air           NEW YORK, NY
# 8                   ALBANIA                        Air           NEW YORK, NY
# 9                   ALBANIA                        Air           NEW YORK, NY
#
#         i94res
# 0      ECUADOR
# 1  SOUTH KOREA
# 2      ALBANIA
# 3      ALBANIA
# 4      ALBANIA
# 5      ALBANIA
# 6      ALBANIA
# 7      ALBANIA
# 8      ALBANIA
# 9      ALBANIA

# %%
# load i94visa dictionary - map the i94visa values
i94visa_dictionary_spark_df=spark \
    .read \
    .format('csv') \
    .options(header='true', inferSchema='true', encoding="ISO-8859-1") \
    .load(f'{input_data_dir}/dictionary_data/i94visa_dictionary.csv')

i94_immigration_spark_df = i94_immigration_spark_df \
    .join(i94visa_dictionary_spark_df, i94_immigration_spark_df.i94visa==i94visa_dictionary_spark_df.key, 'left') \
    .drop('key', 'i94visa') \
    .withColumnRenamed('value', 'i94visa')

i94_immigration_spark_df = i94_immigration_spark_df.fillna('NOT_IN_i94visa_DICTIONARY', ['i94visa'])

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon  arrdate  depdate  i94bir  count  dtadfile visapost  \
# 0     6   2016       4  20573.0      NaN      37    1.0      None     None
# 1     7   2016       4  20551.0      NaN      25    1.0  20130811      SEO
# 2    15   2016       4  20545.0  20691.0      55    1.0  20160401     None
# 3    16   2016       4  20545.0  20567.0      28    1.0  20160401     None
# 4    17   2016       4  20545.0  20567.0       4    1.0  20160401     None
# 5    18   2016       4  20545.0  20555.0      57    1.0  20160401     None
# 6    19   2016       4  20545.0  20558.0      63    1.0  20160401     None
# 7    20   2016       4  20545.0  20558.0      57    1.0  20160401     None
# 8    21   2016       4  20545.0  20553.0      46    1.0  20160401     None
# 9    22   2016       4  20545.0  20562.0      48    1.0  20160401     None
#
#   occup entdepa entdepd entdepu matflag  biryear   dtaddto gender insnum  \
# 0  None       T    None       U    None   1979.0  10282016   None   None
# 1  None       G    None       Y    None   1991.0       D/S      M   None
# 2  None       T       O    None       M   1961.0  09302016      M   None
# 3  None       O       O    None       M   1988.0  09302016   None   None
# 4  None       O       O    None       M   2012.0  09302016   None   None
# 5  None       O       O    None       M   1959.0  09302016   None   None
# 6  None       O       K    None       M   1953.0  09302016   None   None
# 7  None       O       K    None       M   1959.0  09302016   None   None
# 8  None       O       O    None       M   1970.0  09302016   None   None
# 9  None       O       O    None       M   1968.0  09302016   None   None
#
#   airline        admnum  fltno visatype                    i94addr  \
# 0    None  1.897628e+09   None       B2  NOT_IN_i94addr_DICTIONARY
# 1    None  3.736796e+09  00296       F1                    ALABAMA
# 2      OS  6.666432e+08     93       B2                   MICHIGAN
# 3      AA  9.246846e+10  00199       B2              MASSACHUSETTS
# 4      AA  9.246846e+10  00199       B2              MASSACHUSETTS
# 5      AZ  9.247104e+10  00602       B1                   MICHIGAN
# 6      AZ  9.247140e+10  00602       B2                 NEW JERSEY
# 7      AZ  9.247161e+10  00602       B2                 NEW JERSEY
# 8      AZ  9.247080e+10  00602       B2                   NEW YORK
# 9      AZ  9.247849e+10  00608       B1                   NEW YORK
#
#                      i94cit                    i94mode                i94port  \
# 0                   ECUADOR  NOT_IN_i94mode_DICTIONARY  NOT REPORTED/UNKNOWN
# 1  NOT_IN_i94cit_DICTIONARY                        Air            ATLANTA, GA
# 2                   ALBANIA                        Air          WASHINGTON DC
# 3                   ALBANIA                        Air           NEW YORK, NY
# 4                   ALBANIA                        Air           NEW YORK, NY
# 5                   ALBANIA                        Air           NEW YORK, NY
# 6                   ALBANIA                        Air           NEW YORK, NY
# 7                   ALBANIA                        Air           NEW YORK, NY
# 8                   ALBANIA                        Air           NEW YORK, NY
# 9                   ALBANIA                        Air           NEW YORK, NY
#
#         i94res   i94visa
# 0      ECUADOR  Pleasure
# 1  SOUTH KOREA   Student
# 2      ALBANIA  Pleasure
# 3      ALBANIA  Pleasure
# 4      ALBANIA  Pleasure
# 5      ALBANIA  Business
# 6      ALBANIA  Pleasure
# 7      ALBANIA  Pleasure
# 8      ALBANIA  Pleasure
# 9      ALBANIA  Business

# %%
i94_immigration_spark_df = i94_immigration_spark_df.select('cicid', 'i94yr', 'i94mon', 'i94cit', 'i94res', 'i94port', 'arrdate', 'i94mode', 'i94addr', 'depdate', 'i94bir', 'i94visa', 'count', 'dtadfile', 'visapost', 'occup', 'entdepa', 'entdepd', 'entdepu', 'matflag', 'biryear', 'dtaddto', 'gender', 'insnum', 'airline', 'admnum', 'fltno', 'visatype')

# %%
# i94_immigration_spark_df.limit(10).toPandas()
# Out:
#   cicid  i94yr  i94mon                    i94cit       i94res  \
# 0     6   2016       4                   ECUADOR      ECUADOR
# 1     7   2016       4  NOT_IN_i94cit_DICTIONARY  SOUTH KOREA
# 2    15   2016       4                   ALBANIA      ALBANIA
# 3    16   2016       4                   ALBANIA      ALBANIA
# 4    17   2016       4                   ALBANIA      ALBANIA
# 5    18   2016       4                   ALBANIA      ALBANIA
# 6    19   2016       4                   ALBANIA      ALBANIA
# 7    20   2016       4                   ALBANIA      ALBANIA
# 8    21   2016       4                   ALBANIA      ALBANIA
# 9    22   2016       4                   ALBANIA      ALBANIA
#
#                  i94port  arrdate                    i94mode  \
# 0  NOT REPORTED/UNKNOWN   20573.0  NOT_IN_i94mode_DICTIONARY
# 1            ATLANTA, GA  20551.0                        Air
# 2          WASHINGTON DC  20545.0                        Air
# 3           NEW YORK, NY  20545.0                        Air
# 4           NEW YORK, NY  20545.0                        Air
# 5           NEW YORK, NY  20545.0                        Air
# 6           NEW YORK, NY  20545.0                        Air
# 7           NEW YORK, NY  20545.0                        Air
# 8           NEW YORK, NY  20545.0                        Air
# 9           NEW YORK, NY  20545.0                        Air
#
#                      i94addr  depdate  i94bir   i94visa  count  dtadfile  \
# 0  NOT_IN_i94addr_DICTIONARY      NaN      37  Pleasure    1.0      None
# 1                    ALABAMA      NaN      25   Student    1.0  20130811
# 2                   MICHIGAN  20691.0      55  Pleasure    1.0  20160401
# 3              MASSACHUSETTS  20567.0      28  Pleasure    1.0  20160401
# 4              MASSACHUSETTS  20567.0       4  Pleasure    1.0  20160401
# 5                   MICHIGAN  20555.0      57  Business    1.0  20160401
# 6                 NEW JERSEY  20558.0      63  Pleasure    1.0  20160401
# 7                 NEW JERSEY  20558.0      57  Pleasure    1.0  20160401
# 8                   NEW YORK  20553.0      46  Pleasure    1.0  20160401
# 9                   NEW YORK  20562.0      48  Business    1.0  20160401
#
#   visapost occup entdepa entdepd entdepu matflag  biryear   dtaddto gender  \
# 0     None  None       T    None       U    None   1979.0  10282016   None
# 1      SEO  None       G    None       Y    None   1991.0       D/S      M
# 2     None  None       T       O    None       M   1961.0  09302016      M
# 3     None  None       O       O    None       M   1988.0  09302016   None
# 4     None  None       O       O    None       M   2012.0  09302016   None
# 5     None  None       O       O    None       M   1959.0  09302016   None
# 6     None  None       O       K    None       M   1953.0  09302016   None
# 7     None  None       O       K    None       M   1959.0  09302016   None
# 8     None  None       O       O    None       M   1970.0  09302016   None
# 9     None  None       O       O    None       M   1968.0  09302016   None
#
#   insnum airline        admnum  fltno visatype
# 0   None    None  1.897628e+09   None       B2
# 1   None    None  3.736796e+09  00296       F1
# 2   None      OS  6.666432e+08     93       B2
# 3   None      AA  9.246846e+10  00199       B2
# 4   None      AA  9.246846e+10  00199       B2
# 5   None      AZ  9.247104e+10  00602       B1
# 6   None      AZ  9.247140e+10  00602       B2
# 7   None      AZ  9.247161e+10  00602       B2
# 8   None      AZ  9.247080e+10  00602       B2
# 9   None      AZ  9.247849e+10  00608       B1

# %%
spark.stop()
